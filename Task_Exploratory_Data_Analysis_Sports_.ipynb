# %% [markdown]
# # DataSet Link :-  https://github.com/maneaajay/Task_Exploratory-Data-Analysis---Sports

# %% [markdown]
# # Exploratory Data Analysis - Sports
# # Objectives
#
#
# 1.   Perform ‘Exploratory Data Analysis’ on dataset ‘Indian Premier League’
# 2.   As a sports analysts, find out the most successful teams, players and factors contributing win or loss of a team
# 3. Suggest teams or players a company should endorse for its products.
#
# # Importing necessary libraries¶

# %% [markdown]
# # Load Dataset¶

# %% [markdown]
# # Data Cleaning ¶

# %% [markdown]
# # **Visualizations¶**
#
# # **Player of the match most times**
#
# # For Reference
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Highest no of wins¶**
# # For Reference
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# # **Favourite umpires¶**
# # For Reference
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# # **No of matches played in stadium¶**
# # For Reference
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# # **Highest run scorer in IPL¶**
# # For Reference
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# # **Toss Decision to field or bat across seasons¶**
# # for Reference
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# # **Match Played each Season¶**
# # for reference
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# # **Biggest wins by run each Season¶**
# # for reference
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# # **Stadium wise winnings¶**
# # For Reference
# ![9.png](data:image/png;base64,...)
# ![9.11.png](data:image/png;base64,...)
# ![9.2.png](data:image/png;base64,...)
# ![9.3.png](data:image/png;base64,...)

# %% [markdown]
# # **Total Runs each season¶**
# # for Reference
# ![10.png](data:image/png;base64,...)

# %% [markdown]
# # **Boundaries¶**
# # For Reference
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# # **Highest Run by teams¶**
# # for Reference
# ![13.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Orange cup Run¶**
# # for Reference
# ![14.png](data:image/png;base64,...)

# %% [markdown]
# # **Purple Cap Wicket¶**
# # for Reference
# ![15.png](data:image/png;base64,...)

# %% [markdown]
# # **Final match wins¶**
# # for Reference
# ![16.png](data:image/png;base64,...)

# %% [markdown]
# # **Highest Run Scorer¶**
# # for REF
# ![17.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Conlusions:-¶**
